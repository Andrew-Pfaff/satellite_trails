# %% [markdown]
# # Tune ASTA-style postprocessing
#
# This notebook runs the validation-only grid sweep over ASTA-style Hough and cleanup parameters.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/satellite_trails
# !pip install -e .[dev]

# %%
from pathlib import Path

REPO_DIR = Path('/content/drive/MyDrive/satellite_trails')
INPUT_DIR = REPO_DIR / 'data/val_images'
OUTPUT_CSV = REPO_DIR / 'results/postprocess_tuning/validation_grid_results.csv'

# %%
import subprocess

cmd = [
    'python', 'scripts/python/tune_postprocessing.py',
    '--input-dir', str(INPUT_DIR),
    '--output-csv', str(OUTPUT_CSV),
]

print(' '.join(cmd))
subprocess.run(cmd, check=True)

# %%
import pandas as pd

results = pd.read_csv(OUTPUT_CSV)
results.sort_values('iou', ascending=False).head(10)
